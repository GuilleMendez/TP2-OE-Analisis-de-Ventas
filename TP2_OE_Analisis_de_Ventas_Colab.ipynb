# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilleMendez/TP2-OE-Analisis-de-Ventas/blob/Vinculacion-a-Google-Colab/TP2_OE_Analisis_de_Ventas_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/TP Intengrador/AnalisisDeVentas

import csv
from datetime import datetime

# ---------------------------------------------------------
# Cargar ventas desde el archivo CSV
# ---------------------------------------------------------
def cargar_ventas():
    ventas = [] #creo la varibale ventas, usando una tabla


    with open("/content/drive/MyDrive/Colab Notebooks/TP Intengrador/AnalisisDeVentas/sales_sample_2024.csv",
              "r", encoding="utf-8") as archivo:  # abro el archivo en modo lectura

        lector = csv.DictReader(archivo)
        for fila in lector: #utilizo un for para que recorra todos los valores
            venta = {
                "id": int(fila["id"]),
                "fecha": datetime.strptime(fila["sales_date"], "%Y-%m-%d"),
                "monto": float(fila["sales_amount"])
            }
            ventas.append(venta) #utilizo un append para agregar a la variable creada inicialmente
    return ventas

# ---------------------------------------------------------
# Ventas totales del año
# ---------------------------------------------------------
def ventas_totales(ventas):
    return sum(v["monto"] for v in ventas) #retorno la suma de "monto" de las ventas

# ---------------------------------------------------------
# Día con mayor venta
# ---------------------------------------------------------
def dia_mayor_venta(ventas):
    return max(ventas, key=lambda v: v["monto"])

# ---------------------------------------------------------
# Ventas por mes (YYYY-MM)
# ---------------------------------------------------------
def ventas_por_mes(ventas):
    resumen = {} #creo la variable resumen a modo de diccionario para acumular ventas por mes
    for v in ventas:
        mes = v["fecha"].strftime("%Y-%m")
        resumen[mes] = resumen.get(mes, 0) + v["monto"] #si el mes no existe lo crea, sino lo suma
    return resumen #recorro los valores con un for y guardo los valores

# ---------------------------------------------------------
# Mostrar ventas mensuales en forma de tabla
# ---------------------------------------------------------
def mostrar_tabla_ventas_mensuales(ventas_mensuales):
    print("\n=== Ventas por mes ===")
    print(f"{'Mes':<10} | {'Ventas ($)':>12}")
    print("-" * 25)
    for mes, monto in ventas_mensuales.items():
        print(f"{mes:<10} | ${monto:>12,.2f}")

# ---------------------------------------------------------
# Programa principal
# ---------------------------------------------------------
def main():
    ventas = cargar_ventas() #llamo a la funcion cargar ventas, la cual abre el archivo csv

    print("=== Indicadores de Ventas 2024 ===")
    print(f"Ventas totales del año: ${ventas_totales(ventas):,.2f}")

    mayor = dia_mayor_venta(ventas) #defino la variable mayor, llamando a dia_mayor_venta, que la busca usando max()
    print(f"Día con mayor venta: {mayor['fecha'].strftime('%Y-%m-%d')} (${mayor['monto']:,.2f})")

    ventas_mensuales = ventas_por_mes(ventas) #invocamos a las ventas por mes declaradas mas arriba
    mostrar_tabla_ventas_mensuales(ventas_mensuales)

# Ejecutamos
main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/TP Intengrador/AnalisisDeVentas
# === Indicadores de Ventas 2024 ===
# Ventas totales del año: $1,812,114.00
# Día con mayor venta: 2024-03-20 ($8,960.00)
#
# === Ventas por mes ===
# Mes        |   Ventas ($)
# -------------------------
# 2024-01    | $  149,987.00
# 2024-02    | $  136,051.00
# 2024-03    | $  155,495.00
# 2024-04    | $  160,865.00
# 2024-05    | $  150,351.00
# 2024-06    | $  139,237.00
# 2024-07    | $  146,260.00
# 2024-08    | $  156,214.00
# 2024-09    | $  173,024.00
# 2024-10    | $  127,380.00
# 2024-11    | $  152,739.00
# 2024-12    | $  164,511.00
